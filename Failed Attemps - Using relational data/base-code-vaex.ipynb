# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import vaex

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
input_files = []

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if("inp" in filename):
            print(filename)
            df_tmp = vaex.from_csv(file, convert=True, copy_index=False)

print("out of loop")
# combined_input = vaex.concat(input_files)
# combined_input.export_parquet("/kaggle/working/all_inputs.parquet")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import vaex

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
input_files = []
output_files = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(filename)
        df = vaex.from_csv(os.path.join(dirname, filename))
        if("inp" in filename):
            input_files.append(df)
        elif("outp" in filename):
            output_files.append(df)

combined_input = vaex.concat(input_files)
combined_output = vaex.concat(output_files)

combined_input.export_parquet("/kaggle/working/all_inputs.parquet")
combined_output.export_parquet(r"/kaggle/working/all_outputs.parquet")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import vaex

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
input_files = []

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if("inp" in filename):
            print(filename)
            df_tmp = vaex.from_csv(os.path.join(dirname, filename))
            df_tmp.export(os.path.join(r".", filename.replace("txt", "hdf5")))

print("out of loop")
# combined_input = vaex.concat(input_files)
# combined_input.export_parquet("/kaggle/working/all_inputs.parquet")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if("inp" in filename):
            print(os.path.join(dirname,filename))

# %%
## Phase 1 of reading data - convert text files to hdf5 format

import os
import vaex
import pandas as pd

# list_input_files = [os.path.join(r"/kaggle/input/2015-bitcoin-data", f) for f in os.listdir('/kaggle/input/2015-bitcoin-data') if "input" in f]
# list_output_files = [os.path.join(r"/kaggle/input/2015-bitcoin-data", f) for f in os.listdir('/kaggle/input/2015-bitcoin-data') if "output" in f]

list_input_files = [ '/kaggle/input/2015-bitcoin-data/inputs2015_7.txt',
 '/kaggle/input/2015-bitcoin-data/inputs2015_12.txt',
 '/kaggle/input/2015-bitcoin-data/inputs2015_5.txt',
 '/kaggle/input/2015-bitcoin-data/inputs2015_11.txt']
for f in list_input_files:
    df_tmp = vaex.from_csv(f, copy_index=False, sep = "\t", header = None, names = range(1,50))
    df_tmp.export(os.path.join(r".", f.split("/")[-1].replace("txt", "hdf5")))
    del df_tmp
    print(f"Done... {f}")
    
# list_input_filesdf = vaex.from_csv(os.path.join(r"/kaggle/input/2015-bitcoin-data/inputs*.txt"), sep = "\t", header = None, names = range(1,50))

# %%
df.head()

# %%
list_input_files = [os.path.join(r"/kaggle/input/2015-bitcoin-data", f) for f in os.listdir('/kaggle/input/2015-bitcoin-data') if "input" in f]
list_output_files = [os.path.join(r"/kaggle/input/2015-bitcoin-data", f) for f in os.listdir('/kaggle/input/2015-bitcoin-data') if "output" in f]

# %%
j = 1
print(f"value of j is {j}")

# %%
for f in list_input_files:
   print( f.split("/")[-1].replace("txt", "hdf5"))

# %%
import os
import vaex
import pandas as pd

list_input_files = [os.path.join(r"/kaggle/input/2015-bitcoin-data", f) for f in os.listdir('/kaggle/input/2015-bitcoin-data') if "input" in f]
list_output_files = [os.path.join(r"/kaggle/input/2015-bitcoin-data", f) for f in os.listdir('/kaggle/input/2015-bitcoin-data') if "output" in f]

# %%
list_input_files
